# %%
import requests
import numpy as np
import json
import pandas as pd
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
apikey='RGAPI-00529192-40b0-4eb7-9a90-d0d219e1dbbb'
myresp= requests.get('https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/reydeloscriollos?api_key={}'.format(apikey))
apimatch='uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA'
sndresp=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{}/ids?start=0&count=100&api_key={}'.format(apimatch,apikey))

listnew=[]
itera=500
while itera>0:
    response=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{}/ids?start={}&count=100&api_key={}'.format(apimatch,itera,apikey))
    
    listnew.extend(response.json())
    itera-= 100
    print(itera)
# Out:
# 400
# 300
# 200
# 100
# 0

# %%
with open(r'C:\Users\amird\mydata.json') as f:
  data = json.load(f)
df_pd=pd.DataFrame(data)

# %%
df_pd
# Out:
#       assists  baronKills  bountyLevel  champExperience  champLevel  \
# 0           4           0            0            15858          16
# 1           3           0            0             9114          12
# 2          10           0            0            14556          15
# 3           3           0            0             9892          12
# 4          10           0            0             9598          12
# ...       ...         ...          ...              ...         ...
# 4915        2           0            0            15734          16
# 4916        9           0            0            17412          17
# 4917        7           0            0            19610          18
# 4918        5           0            0            15058          16
# 4919       15           0            2            17789          17
#
#       championId  championName  championTransform  consumablesPurchased  \
# 0       37225015      Renekton                  0                     1
# ...

# %%
sndresp
# Out:
# <Response [200]>

# %%
myresp
# Out:
# <Response [200]>

# %%
myresp.json()
# Out:
# {'id': 'Zr3bU2qyYpWHVbYLvtDAt90_eoWeIqeXWQDjSp7Ge2P4dpA',
#  'accountId': 'nkMZ3lwiYvu9d5XJ6zAV28of2jbQuUugYpN6i8R8XqvfoA',
#  'puuid': 'uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA',
#  'name': 'reydeloscriollos',
#  'profileIconId': 4804,
#  'revisionDate': 1622004320640,
#  'summonerLevel': 199}

# %%
vari
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_3892514620',
#   'participants': ['BQ0TUFr7T0xgeWO_z-1Yh3Fj2pjYZulLWFC-k-uyeNr5r3RsZ2HGdQ29u2Owv-C5szgk9Z6eOjUmFQ',
#    'pHodc6-txFvu9F7dWtfxV3fplDeGTlvkfcxWL_Wd5KJKSHYB7RERsRcodOV64qVKnzdpPy_OvM85xg',
#    'uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA',
#    'Na-SzBaz60B3SSoidYAXTTu2wxJNtKx_hpXZGSAzigVJC4qMSg74-fqcyKoCwuf2xkBE8_YQ7EZ4nA',
#    'rIVnf2LEsNLP2AUe9D4duM97_0Kz8D-GtbUrPlCnKrgNt2vSVABJmEXLxZfxNg0CC1j2l4wDwkRkhA',
#    'lGJ1T3v-hkPIxEywwnVTej8gkFkCrRCCEAzUF9MY2o1Bx0rKN53gdCqZkbANGOymUCa1J7GeUTTcRw',
#    '5DeFx5OL0MHO9e3YiyW-v2o6bF7q254zM68AbAuhnCFPCAg3bWQbz-UmeFf4ROJk84SP5l6hjC5EcA',
#    'F-W_0-Io4_9ySNRhDlg64-h-yGDT4SmWUfmaKXgysgsbR8Aon47TVg80d2OGj_0ef85b4nSDfPR2MA',
#    'GL4vSxnkZGKELY2qq_ErUzUMI7qdLhuQGdJhzKRYacPISyEouHhTqmzQF9QcoeClOCVsb5yx4ZJEyA',
#    'HM8HPC-kq37gMdOOpw4MhdwqYvNemjoh6W34FmnfAbslRClWAL6cNFIISYKZB-2UyknYLG78B8GTtg']},
#  'info': {'gameCreation': 1620082989000,
# ...

# %%
sndresp.json()
type(sndresp.json())
sndresp.json()
# Out:
# ['NA1_3925051433',
#  'NA1_3925046446',
#  'NA1_3924666374',
#  'NA1_3924247766',
#  'NA1_3924110925',
#  'NA1_3923909128',
#  'NA1_3923894819',
#  'NA1_3923920109',
#  'NA1_3922817951',
#  'NA1_3922699366',
#  'NA1_3922681099',
#  'NA1_3922620661',
#  'NA1_3922464533',
#  'NA1_3922510767',
#  'NA1_3921761716',
#  'NA1_3921735720',
#  'NA1_3920661527',
#  'NA1_3920587787',
#  'NA1_3920612557',
#  'NA1_3920475584',
#  'NA1_3920230954',
#  'NA1_3920215815',
#  'NA1_3920139013',
#  'NA1_3919178677',
#  'NA1_3919202562',
#  'NA1_3919008456',
#  'NA1_3918028011',
#  'NA1_3917736642',
#  'NA1_3917764300',
#  'NA1_3917679496',
#  'NA1_3917522348',
#  'NA1_3917439203',
#  'NA1_3917435765',
#  'NA1_3917452780',
#  'NA1_3916226104',
#  'NA1_3916047317',
#  'NA1_3916044651',
#  'NA1_3915711010',
#  'NA1_3915605597',
#  'NA1_3915551404',
#  'NA1_3915476334',
#  'NA1_3915458908',
#  'NA1_3915395803',
#  'NA1_3915389364',
#  'NA1_3914273034',
#  'NA1_3914197561',
#  'NA1_3914193452',
# ...

# %%
test_match=listnew
test_match

dictionaryOfPlayers={}
counter=0

for item in test_match:
    
    
    time.sleep(3)
    my_match_in_for=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(item,apikey))
    vari=my_match_in_for.json()
    if 'status' not in vari:
        dictionaryOfPlayers[counter]= vari['info']['participants']
    else:
        continue
    counter+=1

# %%
counter

# %%
dictionaryOfPlayers.to_json('C:\data.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-82cdd0665117> in <module>
# ----> 1 dictionaryOfPlayers.to_json('C:\data.json')
#
# AttributeError: 'dict' object has no attribute 'to_json'

# %%
for player in dictionaryOfPlayers[0]:
    print(player)
    del player['perks']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ee00ff559094> in <module>
# ----> 1 for player in dictionaryOfPlayers[0]:
#       2     print(player)
#       3     del player['perks']
#
# NameError: name 'dictionaryOfPlayers' is not defined

# %%
list_of_frames=[]
for dataframe2 in  dictionaryOfPlayers:
    list_of_frames.append(pd.DataFrame(dictionaryOfPlayers[dataframe2]))
    
    
df_pd=pd.concat(list_of_frames,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f69d9e371997> in <module>
#       1 list_of_frames=[]
# ----> 2 for dataframe2 in  dictionaryOfPlayers:
#       3     list_of_frames.append(pd.DataFrame(dictionaryOfPlayers[dataframe2]))
#       4
#       5
#
# NameError: name 'dictionaryOfPlayers' is not defined

# %%
del df_pd['perks']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'perks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-2ebfba1aa6ae> in <module>
# ...

# %%
### this is just just test code this can be ignored
to_conca=[pd.DataFrame(dictionaryOfPlayers[1]),pd.DataFrame(dictionaryOfPlayers[0])]
findat=pd.concat(to_conca,ignore_index=True)

findat
# Out:
#     assists  baronKills  bountyLevel  champExperience  champLevel  championId  \
# 0         4           0            9             9704          12    37225015
# 1         4           0            1             7295          10    37290552
# 2         3           0            6            11150          13    37356089
# 3         5           0            2             8049          11    37421626
# 4         9           0            1             7383          11    37487163
# 5         0           0            0             6639          10    37552700
# 6         1           0            0             6083           9    37618237
# 7         0           0            0             6805          10    37683774
# 8         1           0            0             5196           9    37749311
# 9         2           0            0             4594           8    37814848
# 10        4           0            0            15858          16    37225015
# ...

# %%
for item in df_pd.columns:
    print(item)
# Out:
# assists
# baronKills
# bountyLevel
# champExperience
# champLevel
# championId
# championName
# championTransform
# consumablesPurchased
# damageDealtToObjectives
# damageDealtToTurrets
# damageSelfMitigated
# deaths
# detectorWardsPlaced
# doubleKills
# dragonKills
# firstBloodAssist
# firstBloodKill
# firstTowerAssist
# firstTowerKill
# gameEndedInEarlySurrender
# gameEndedInSurrender
# goldEarned
# goldSpent
# individualPosition
# inhibitorKills
# item0
# item1
# item2
# item3
# item4
# item5
# item6
# itemsPurchased
# killingSprees
# kills
# lane
# largestCriticalStrike
# largestKillingSpree
# largestMultiKill
# longestTimeSpentLiving
# magicDamageDealt
# magicDamageDealtToChampions
# magicDamageTaken
# neutralMinionsKilled
# nexusKills
# objectivesStolen
# objectivesStolenAssists
# participantId
# pentaKills
# physicalDamageDealt
# physicalDamageDealtToChampions
# physicalDamageTaken
# profileIcon
# puuid
# quadraKills
# riotIdName
# riotIdTagline
# role
# ...

# %%
df_pd.info
amirs_games=df_pd.loc[df_pd['summonerName']=='reydeloscriollos']
amirs_games
# Out:
#       assists  baronKills  bountyLevel  champExperience  champLevel  \
# 2          10           0            0            14556          15
# 17          0           0            0             6805          10
# 27          5           0            1             8539          11
# 32          9           0            4            14914          16
# 49         11           0            0            10697          13
# ...       ...         ...          ...              ...         ...
# 4872        0           0            0            11529          14
# 4888        3           0            0            14280          15
# 4893        3           0            0             8316          11
# 4904        5           0            0            15362          16
# 4916        9           0            0            17412          17
#
#       championId championName  championTransform  consumablesPurchased  \
# 2       37356089        Senna                  0                     1
# ...

# %%
df_pd.to_json(r'C:\Users\amird\mydata.json')

# %%
amirs_games['win'].map(lambda x: 'win' if x==True else 'loss')
# Out:
# 2       loss
# 17      loss
# 27      loss
# 32       win
# 49      loss
#         ...
# 4872    loss
# 4888    loss
# 4893    loss
# 4904    loss
# 4916    loss
# Name: win, Length: 492, dtype: object

# %%
amirs_games["item0"]=amirs_games["item0"].astype(str)
amirs_games["item2"]=amirs_games["item2"].astype(str)
amirs_games["item3"]=amirs_games["item3"].astype(str)
amirs_games["item4"]=amirs_games["item4"].astype(str)
amirs_games["item5"]=amirs_games["item5"].astype(str)
amirs_games["item6"]=amirs_games["item6"].astype(str)
amirs_games["win"]=amirs_games['win'].map(lambda x: 'win' if x==True else 'loss')
# Out:
# <ipython-input-9-db95239886b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item0"]=amirs_games["item0"].astype(str)
# <ipython-input-9-db95239886b4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item2"]=amirs_games["item2"].astype(str)
# <ipython-input-9-db95239886b4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
item_versionlist=requests.get('https://ddragon.leagueoflegends.com/api/versions.json')
item_req=requests.get('http://ddragon.leagueoflegends.com/cdn/{}/data/en_US/item.json'.format(item_versionlist.json()[0]))

# %%
file=item_req.json()
file
# Out:
# {'type': 'item',
#  'version': '11.11.1',
#  'basic': {'name': '',
#   'rune': {'isrune': False, 'tier': 1, 'type': 'red'},
#   'gold': {'base': 0, 'total': 0, 'sell': 0, 'purchasable': False},
#   'group': '',
#   'description': '',
#   'colloq': ';',
#   'plaintext': '',
#   'consumed': False,
#   'stacks': 1,
#   'depth': 1,
#   'consumeOnFull': False,
#   'from': [],
#   'into': [],
#   'specialRecipe': 0,
#   'inStore': True,
#   'hideFromAll': False,
#   'requiredChampion': '',
#   'requiredAlly': '',
#   'stats': {'FlatHPPoolMod': 0,
#    'rFlatHPModPerLevel': 0,
#    'FlatMPPoolMod': 0,
#    'rFlatMPModPerLevel': 0,
#    'PercentHPPoolMod': 0,
#    'PercentMPPoolMod': 0,
#    'FlatHPRegenMod': 0,
#    'rFlatHPRegenModPerLevel': 0,
#    'PercentHPRegenMod': 0,
#    'FlatMPRegenMod': 0,
#    'rFlatMPRegenModPerLevel': 0,
#    'PercentMPRegenMod': 0,
#    'FlatArmorMod': 0,
#    'rFlatArmorModPerLevel': 0,
#    'PercentArmorMod': 0,
#    'rFlatArmorPenetrationMod': 0,
# ...

# %%
dictionaryOfItems={}

for itemnum in file['data']:
    
    dictionaryOfItems[itemnum]=file['data'][itemnum]['name']

dictionaryOfItems
# Out:
# {'1001': 'Boots',
#  '1004': 'Faerie Charm',
#  '1006': 'Rejuvenation Bead',
#  '1011': "Giant's Belt",
#  '1018': 'Cloak of Agility',
#  '1026': 'Blasting Wand',
#  '1027': 'Sapphire Crystal',
#  '1028': 'Ruby Crystal',
#  '1029': 'Cloth Armor',
#  '1031': 'Chain Vest',
#  '1033': 'Null-Magic Mantle',
#  '1035': 'Emberknife',
#  '1036': 'Long Sword',
#  '1037': 'Pickaxe',
#  '1038': 'B. F. Sword',
#  '1039': 'Hailblade',
#  '1042': 'Dagger',
#  '1043': 'Recurve Bow',
#  '1052': 'Amplifying Tome',
#  '1053': 'Vampiric Scepter',
#  '1054': "Doran's Shield",
#  '1055': "Doran's Blade",
#  '1056': "Doran's Ring",
#  '1057': 'Negatron Cloak',
#  '1058': 'Needlessly Large Rod',
#  '1082': 'Dark Seal',
#  '1083': 'Cull',
#  '2003': 'Health Potion',
#  '2010': 'Total Biscuit of Everlasting Will',
#  '2015': 'Kircheis Shard',
#  '2031': 'Refillable Potion',
#  '2033': 'Corrupting Potion',
#  '2051': "Guardian's Horn",
#  '2052': 'Poro-Snax',
#  '2055': 'Control Ward',
# ...

# %%
amirs_games["item0"]=amirs_games["item0"].map(dictionaryOfItems)
amirs_games["item1"]=amirs_games["item1"].map(dictionaryOfItems)
amirs_games["item2"]=amirs_games["item2"].map(dictionaryOfItems)
amirs_games["item3"]=amirs_games["item3"].map(dictionaryOfItems)
amirs_games["item4"]=amirs_games["item4"].map(dictionaryOfItems)
amirs_games["item5"]=amirs_games["item5"].map(dictionaryOfItems)
amirs_games["item6"]=amirs_games["item6"].map(dictionaryOfItems)
# Out:
# <ipython-input-13-6d8d4153d10b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item0"]=amirs_games["item0"].map(dictionaryOfItems)
# <ipython-input-13-6d8d4153d10b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item1"]=amirs_games["item1"].map(dictionaryOfItems)
# <ipython-input-13-6d8d4153d10b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
amirs_games['win']
# Out:
# 2       loss
# 17      loss
# 27      loss
# 32       win
# 49      loss
#         ...
# 4872    loss
# 4888    loss
# 4893    loss
# 4904    loss
# 4916    loss
# Name: win, Length: 492, dtype: object

# %%
new=amirs_games[['championName','win']]
amirs_games.groupby(['championName','win']).count()
# Out:
#                    assists  baronKills  bountyLevel  champExperience  \
# championName win
# Ahri         win         1           1            1                1
# Bard         loss        1           1            1                1
# Caitlyn      loss        1           1            1                1
#              win         2           2            2                2
# Cassiopeia   loss        2           2            2                2
# ...                    ...         ...          ...              ...
# Xayah        win         1           1            1                1
# Yasuo        loss        1           1            1                1
#              win         4           4            4                4
# Yone         loss       10          10           10               10
#              win        10          10           10               10
#
#                    champLevel  championId  championTransform  \
# championName win
# ...

# %% [raw]
# vram=amirs_games.groupby(['championName','win']).agg({'assists':'sum'})
# vram2=vram.groupby(level=0).apply(lambda x: 100*x / float(x.sum())).reset_index()
# highestWinRate=vram2.loc[(vram2['win']=='win')&(vram2['assists']> 50.0)]
#
# highestWinRate

# %%
vram=amirs_games.groupby(['championName','win']).agg({'assists':'sum'})
vram2=vram.groupby(level=0).apply(lambda x: 100*x / float(x.sum())).reset_index()
highestWinRate=vram2.loc[(vram2['win']=='win')&(vram2['assists']> 50.0)]

highestWinRate
# Out:
#    championName  win     assists
# 0          Ahri  win  100.000000
# 3       Caitlyn  win   84.210526
# 5        Draven  win  100.000000
# 7         Garen  win   94.117647
# 11      Hecarim  win  100.000000
# 17      Karthus  win  100.000000
# 23       Lucian  win   57.647059
# 27     Malzahar  win   52.422907
# 29     MasterYi  win   65.217391
# 33        Nasus  win   52.631579
# 34         Olaf  win  100.000000
# 36        Quinn  win   52.631579
# 40       Samira  win   66.331658
# 42        Senna  win   60.586797
# 44    Seraphine  win   67.029973
# 46      Shyvana  win  100.000000
# 47         Sona  win  100.000000
# 49       Soraka  win   85.185185
# 52        Taric  win  100.000000
# 53     Tristana  win  100.000000
# 54       Twitch  win  100.000000
# 56        Varus  win   84.615385
# 57        Vayne  win  100.000000
# 62        Xayah  win   71.428571
# 64        Yasuo  win   93.548387
# 66         Yone  win   72.058824

# %%
listChamp=list(highestWinRate['championName'])
type(listChamp)
listChamp

amirs_games[(amirs_games['championName'].isin(listChamp))]
# Out:
#       assists  baronKills  bountyLevel  champExperience  champLevel  \
# 2          10           0            0            14556          15
# 17          0           0            0             6805          10
# 27          5           0            1             8539          11
# 32          9           0            4            14914          16
# 49         11           0            0            10697          13
# ...       ...         ...          ...              ...         ...
# 4867        5           0            2            13113          15
# 4872        0           0            0            11529          14
# 4888        3           0            0            14280          15
# 4893        3           0            0             8316          11
# 4904        5           0            0            15362          16
#
#       championId championName  championTransform  consumablesPurchased  \
# 2       37356089        Senna                  0                     1
# ...

# %%
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-84ddba356ca3> in <module>
# ----> 1 var
#
# NameError: name 'var' is not defined

# %%
var=amirs_games.groupby('championName').count().reset_index()
playedmorethanten=var.loc[var['assists']>5,['championName']]

playedmorethanten=list(playedmorethanten['championName'])
playedmorethanten
# amirs_games[amirs_games['championName'].map(amirs_games['championName'].value_counts())>1]
# Out:
# ['Gwen',
#  'Lucian',
#  'Malzahar',
#  'Nasus',
#  'Samira',
#  'Senna',
#  'Seraphine',
#  'Varus',
#  'Warwick',
#  'Yone']

# %%
NEXTdf=amirs_games[(amirs_games['championName'].isin(listChamp)) & (amirs_games['championName'].isin(playedmorethanten))]
NEXTdf
# Out:
#       assists  baronKills  bountyLevel  champExperience  champLevel  \
# 2          10           0            0            14556          15
# 17          0           0            0             6805          10
# 27          5           0            1             8539          11
# 32          9           0            4            14914          16
# 49         11           0            0            10697          13
# ...       ...         ...          ...              ...         ...
# 4857       14           0            0            19846          18
# 4867        5           0            2            13113          15
# 4872        0           0            0            11529          14
# 4893        3           0            0             8316          11
# 4904        5           0            0            15362          16
#
#       championId championName  championTransform  consumablesPurchased  \
# 2       37356089        Senna                  0                     1
# ...

# %%
#'''sorted the data once again for next analysis to get rid of unwanted champs,  
#first analysis is to look at highest kill rate

# %%
# just wanted to see the best champs by percentage i have filtering it out

vram3=NEXTdf.groupby(['championName','win']).agg({'assists':'sum'})
vram4=vram3.groupby(level=0).apply(lambda x: 100*x / float(x.sum())).reset_index()
highestWinRate2=vram4.loc[(vram4['win']=='win')&(vram4['assists']> 50.0)]

highestWinRate2
# Out:
#    championName  win    assists
# 1        Lucian  win  57.647059
# 3      Malzahar  win  52.422907
# 5         Nasus  win  52.631579
# 7        Samira  win  66.331658
# 9         Senna  win  60.586797
# 11    Seraphine  win  67.029973
# 13        Varus  win  84.615385
# 15         Yone  win  72.058824

# %%
for namechamp in highestWinRate2['championName']:
    
    NEXTdf[NEXTdf['championName']==namechamp].boxplot(['totalDamageDealtToChampions','totalDamageTaken'], by='win', figsize=(8,12))
    plt.suptitle(namechamp)
    
;

# NEXTdf[NEXTdf['championName']=='Malzahar'].boxplot('totalDamageDealtToChampions', by='win')
# Out:
# ''

# %%
for namechamp in highestWinRate2['championName']:
    
    NEXTdf[NEXTdf['championName']==namechamp].boxplot(['deaths','kills'], by='win', figsize=(8,12))
    plt.suptitle(namechamp)
    
;
# Out:
# ''

# %%
#### Now lets take a look at time spent in game 

NEXTdf.groupby(['championName','win']).mean()['timePlayed'].plot(kind='bar')
plt.ylim([20,45])
# Out:
# (20.0, 45.0)

# %%
appenditem=[]

# for items in range(len(NEXTdf)):
    
#     ite1=list(NEXTdf.loc[:,'item0'])
#     ite2=list(NEXTdf.loc[:,'item1'])
#     ite3=list(NEXTdf.loc[:,'item2'])
#     ite4=list(NEXTdf.loc[:,'item3'])
#     ite5=list(NEXTdf.loc[:,'item4'])
    
#     appenditem.extend([ite1,ite2,ite3,ite4,ite5])
#     for item in list(NEXTdf.championName.unique()):
        
#         print(item)
# Out:
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# Senna
# ...

# %%
groupedloss=NEXTdf.groupby(['championName','win','item0'])['item2'].count()
groupedloss['Senna']['loss'].plot.bar(stacked=True,subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'item2'}, xlabel='item0'>],
#       dtype=object)

# %%
groupedwin=NEXTdf.groupby(['championName','win','item0'])['item2'].count()
groupedwin['Senna']['win'].plot.bar(stacked=True,subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'item2'}, xlabel='item0'>],
#       dtype=object)

# %%
NEXTdf.groupby(['championName','win','item0'])['item2'].count()
# Out:
# championName  win   item0
# Lucian        loss  B. F. Sword            1
#                     Berserker's Greaves    2
#                     Doran's Blade          4
#                     Galeforce              3
#                     Immortal Shieldbow     2
#                                           ..
# Yone          win   Mortal Reminder        2
#                     Phantom Dancer         1
#                     Spirit Visage          1
#                     Wit's End              1
#                     Youmuu's Ghostblade    1
# Name: item2, Length: 129, dtype: int64

# %%
NEXTdf.corr()
# Out:
#                          assists  baronKills  bountyLevel  champExperience  \
# assists                 1.000000    0.235929     0.184320         0.722632
# baronKills              0.235929    1.000000     0.128495         0.201384
# bountyLevel             0.184320    0.128495     1.000000         0.157304
# champExperience         0.722632    0.201384     0.157304         1.000000
# champLevel              0.632675    0.197910     0.169452         0.933255
# ...                          ...         ...          ...              ...
# wardsPlaced             0.450244    0.204206     0.009500         0.511924
# damageDealtToBuildings  0.408651    0.182985     0.393959         0.436917
# inhibitorsLost         -0.044787   -0.169446    -0.374144         0.184634
# nexusLost              -0.220193   -0.188443    -0.470222         0.003860
# turretsLost            -0.040184   -0.075843    -0.412195         0.252858
#
#                         champLevel  championId  championTransform  \
# ...

# %%
trimNEXTdf=NEXTdf.drop(['sightWardsBoughtInGame','nexusLost','turretsLost','inhibitorsLost', 'visionWardsBoughtInGame', 'wardsKilled', 'wardsPlaced', 'turretKills', 'unrealKills', 'tripleKills', 'totalDamageShieldedOnTeammates', 'teamId', 'teamPosition', 'spell1Casts', 'spell2Casts', 'spell3Casts', 'spell4Casts', 'summoner1Casts', 'summoner1Id', 'summoner2Casts', 'summoner2Id', 'summonerId', 'summonerLevel', 'summonerName', 'riotIdName', 'riotIdTagline', 'role', 'objectivesStolen', 'objectivesStolenAssists', 'participantId', 'pentaKills', 'physicalDamageDealt', 'physicalDamageDealtToChampions', 'physicalDamageTaken', 'profileIcon', 'puuid', 'neutralMinionsKilled', 'nexusKills', 'magicDamageDealt', 'magicDamageDealtToChampions', 'magicDamageTaken','item0', 'item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'goldEarned', 'goldSpent', 'individualPosition', 'inhibitorKills', 'damageSelfMitigated', 'champLevel', 'championId', 'championName', 'championTransform', 'consumablesPurchased'], axis=1)

# %%
trimNEXTdf["win"]=trimNEXTdf['win'].map(lambda x: 1 if x=='win' else 0)

trimNEXTdf.corr()
# Out:
#                               assists  baronKills  bountyLevel  \
# assists                      1.000000    0.235929     0.184320
# baronKills                   0.235929    1.000000     0.128495
# bountyLevel                  0.184320    0.128495     1.000000
# champExperience              0.722632    0.201384     0.157304
# damageDealtToObjectives      0.453456    0.387591     0.359597
# damageDealtToTurrets         0.349805    0.145997     0.363849
# deaths                       0.239422    0.003117    -0.366728
# detectorWardsPlaced          0.135165    0.149135    -0.060696
# doubleKills                  0.239568    0.204882     0.340029
# dragonKills                  0.117386    0.128467     0.213872
# firstBloodAssist             0.243120   -0.027412     0.020595
# firstBloodKill               0.002947    0.016431     0.025192
# firstTowerAssist             0.001813   -0.045661     0.036834
# firstTowerKill               0.009331   -0.065599     0.015304
# ...

# %%
NEXTdf['timePlayed']=NEXTdf['timePlayed'].map(lambda x: x/60 )
# Out:
# <ipython-input-57-35518581c9a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NEXTdf['timePlayed']=NEXTdf['timePlayed'].map(lambda x: x/60 )

# %%
NEXTdf['timePlayed']
# Out:
# 2       32.633333
# 17      18.733333
# 27      24.400000
# 32      28.083333
# 49      26.800000
#           ...
# 4857    40.716667
# 4867    31.216667
# 4872    23.816667
# 4893    23.483333
# 4904    32.766667
# Name: timePlayed, Length: 399, dtype: float64

# %%
grouped['Senna']['win'].reset_index().item0
# Out:
# ["Caulfield's Warhammer",
#  'Zeal',
#  'Stormrazor',
#  'Serrated Dirk',
#  "Serpent's Fang",
#  'Sanguine Blade',
#  'Pickaxe',
#  'Kircheis Shard',
#  'Eclipse',
#  'Divine Sunderer',
#  'Dagger',
#  "Youmuu's Ghostblade",
#  'Boots of Swiftness',
#  'Umbral Glaive',
#  'The Collector',
#  'Navori Quickblades',
#  'Infinity Edge',
#  'Essence Reaver',
#  "Guinsoo's Rageblade",
#  'Kraken Slayer',
#  'Black Mist Scythe',
#  "Doran's Blade",
#  'Muramana',
#  'Tear of the Goddess']
