# %%
import requests
import json
import pandas as pd
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
apikey='RGAPI-680760d7-79b9-4450-b864-3132fa896c93'
myresp= requests.get('https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/reydeloscriollos?api_key={}'.format(apikey))
apimatch='uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA'
sndresp=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA/ids?start=0&count=50&api_key={}'.format(apikey))

# %%
sndresp
# Out:
# <Response [200]>

# %%
myresp
# Out:
# <Response [200]>

# %%
myresp.json()
# Out:
# {'id': 'Zr3bU2qyYpWHVbYLvtDAt90_eoWeIqeXWQDjSp7Ge2P4dpA',
#  'accountId': 'nkMZ3lwiYvu9d5XJ6zAV28of2jbQuUugYpN6i8R8XqvfoA',
#  'puuid': 'uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA',
#  'name': 'reydeloscriollos',
#  'profileIconId': 4804,
#  'revisionDate': 1620186415000,
#  'summonerLevel': 197}

# %%
vari
# Out:
# {'status': {'message': 'Forbidden', 'status_code': 403}}

# %%
sndresp.json()
type(sndresp.json())
# Out:
# list

# %%
test_match=sndresp.json()
test_match

dictionaryOfPlayers={}
counter=0

for item in test_match:
    
    
    time.sleep(5)
    my_match_in_for=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(item,apikey))
    vari=my_match_in_for.json()
    
    dictionaryOfPlayers[counter]= vari['info']['participants']
    counter+=1

# %%
for player in dictionaryOfPlayers[0]:
    print(player)
    del player['perks']
# Out:
# {'assists': 12, 'baronKills': 0, 'bountyLevel': 6, 'champExperience': 19977, 'champLevel': 18, 'championId': 41, 'championName': 'Gangplank', 'championTransform': 0, 'consumablesPurchased': 3, 'damageDealtToBuildings': 7390, 'damageDealtToObjectives': 14732, 'damageDealtToTurrets': 7390, 'damageSelfMitigated': 33395, 'deaths': 6, 'detectorWardsPlaced': 1, 'doubleKills': 1, 'dragonKills': 0, 'firstBloodAssist': False, 'firstBloodKill': False, 'firstTowerAssist': True, 'firstTowerKill': False, 'gameEndedInEarlySurrender': False, 'gameEndedInSurrender': False, 'goldEarned': 17704, 'goldSpent': 15143, 'individualPosition': 'TOP', 'inhibitorKills': 0, 'inhibitorsLost': 0, 'item0': 3075, 'item1': 3078, 'item2': 6676, 'item3': 3047, 'item4': 6695, 'item5': 3077, 'item6': 3340, 'itemsPurchased': 22, 'killingSprees': 3, 'kills': 11, 'lane': 'TOP', 'largestCriticalStrike': 926, 'largestKillingSpree': 6, 'largestMultiKill': 2, 'longestTimeSpentLiving': 373, 'magicDamageDealt': 29710, 'magicDama
# ...

# %%
list_of_frames=[]
for dataframe2 in  dictionaryOfPlayers:
    list_of_frames.append(pd.DataFrame(dictionaryOfPlayers[dataframe2]))
    
    
df_pd=pd.concat(list_of_frames,ignore_index=True)

# %%
### this is just just test code this can be ignored
to_conca=[pd.DataFrame(dictionaryOfPlayers[1]),pd.DataFrame(dictionaryOfPlayers[0])]
findat=pd.concat(to_conca,ignore_index=True)

findat
# Out:
#     assists  baronKills  bountyLevel  champExperience  champLevel  championId  \
# 0         4           0            0            12868          14          36
# 1         6           0            3            12409          14         141
# 2         5           0            2            11573          14          90
# 3         1           0            0             8725          12         498
# 4        10           0            0             8079          11         147
# 5         1           0            0            10103          13         122
# 6         4           0            0             7694          11          30
# 7         0           0            0            11907          14         157
# 8         0           0            2             9313          12          81
# 9         3           0            0             6644          10         117
# 10       12           0            6            19977          18          41
# ...

# %%
for item in df_pd.columns:
    print(item)
# Out:
# assists
# baronKills
# bountyLevel
# champExperience
# champLevel
# championId
# championName
# championTransform
# consumablesPurchased
# damageDealtToBuildings
# damageDealtToObjectives
# damageDealtToTurrets
# damageSelfMitigated
# deaths
# detectorWardsPlaced
# doubleKills
# dragonKills
# firstBloodAssist
# firstBloodKill
# firstTowerAssist
# firstTowerKill
# gameEndedInEarlySurrender
# gameEndedInSurrender
# goldEarned
# goldSpent
# individualPosition
# inhibitorKills
# inhibitorsLost
# item0
# item1
# item2
# item3
# item4
# item5
# item6
# itemsPurchased
# killingSprees
# kills
# lane
# largestCriticalStrike
# largestKillingSpree
# largestMultiKill
# longestTimeSpentLiving
# magicDamageDealt
# magicDamageDealtToChampions
# magicDamageTaken
# neutralMinionsKilled
# nexusKills
# nexusLost
# objectivesStolen
# objectivesStolenAssists
# participantId
# pentaKills
# physicalDamageDealt
# physicalDamageDealtToChampions
# physicalDamageTaken
# profileIcon
# puuid
# quadraKills
# ...

# %%
df_pd.info
amirs_games=df_pd.loc[df_pd['summonerName']=='reydeloscriollos']

# %%
amirs_games["item0"]=amirs_games["item0"].astype(str)
amirs_games["item2"]=amirs_games["item2"].astype(str)
amirs_games["item3"]=amirs_games["item3"].astype(str)
amirs_games["item4"]=amirs_games["item4"].astype(str)
amirs_games["item5"]=amirs_games["item5"].astype(str)
amirs_games["item6"]=amirs_games["item6"].astype(str)
# Out:
# <ipython-input-152-1abc6715e371>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item0"]=amirs_games["item0"].astype(str)
# <ipython-input-152-1abc6715e371>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item2"]=amirs_games["item2"].astype(str)
# <ipython-input-152-1abc6715e371>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
item_versionlist=requests.get('https://ddragon.leagueoflegends.com/api/versions.json')
item_req=requests.get('http://ddragon.leagueoflegends.com/cdn/{}/data/en_US/item.json'.format(item_versionlist.json()[0]))

# %%
file=item_req.json()
file
# Out:
# {'type': 'item',
#  'version': '11.11.1',
#  'basic': {'name': '',
#   'rune': {'isrune': False, 'tier': 1, 'type': 'red'},
#   'gold': {'base': 0, 'total': 0, 'sell': 0, 'purchasable': False},
#   'group': '',
#   'description': '',
#   'colloq': ';',
#   'plaintext': '',
#   'consumed': False,
#   'stacks': 1,
#   'depth': 1,
#   'consumeOnFull': False,
#   'from': [],
#   'into': [],
#   'specialRecipe': 0,
#   'inStore': True,
#   'hideFromAll': False,
#   'requiredChampion': '',
#   'requiredAlly': '',
#   'stats': {'FlatHPPoolMod': 0,
#    'rFlatHPModPerLevel': 0,
#    'FlatMPPoolMod': 0,
#    'rFlatMPModPerLevel': 0,
#    'PercentHPPoolMod': 0,
#    'PercentMPPoolMod': 0,
#    'FlatHPRegenMod': 0,
#    'rFlatHPRegenModPerLevel': 0,
#    'PercentHPRegenMod': 0,
#    'FlatMPRegenMod': 0,
#    'rFlatMPRegenModPerLevel': 0,
#    'PercentMPRegenMod': 0,
#    'FlatArmorMod': 0,
#    'rFlatArmorModPerLevel': 0,
#    'PercentArmorMod': 0,
#    'rFlatArmorPenetrationMod': 0,
# ...

# %%
dictionaryOfItems={}

for itemnum in file['data']:
    
    dictionaryOfItems[itemnum]=file['data'][itemnum]['name']

dictionaryOfItems
# Out:
# {'1001': 'Boots',
#  '1004': 'Faerie Charm',
#  '1006': 'Rejuvenation Bead',
#  '1011': "Giant's Belt",
#  '1018': 'Cloak of Agility',
#  '1026': 'Blasting Wand',
#  '1027': 'Sapphire Crystal',
#  '1028': 'Ruby Crystal',
#  '1029': 'Cloth Armor',
#  '1031': 'Chain Vest',
#  '1033': 'Null-Magic Mantle',
#  '1035': 'Emberknife',
#  '1036': 'Long Sword',
#  '1037': 'Pickaxe',
#  '1038': 'B. F. Sword',
#  '1039': 'Hailblade',
#  '1042': 'Dagger',
#  '1043': 'Recurve Bow',
#  '1052': 'Amplifying Tome',
#  '1053': 'Vampiric Scepter',
#  '1054': "Doran's Shield",
#  '1055': "Doran's Blade",
#  '1056': "Doran's Ring",
#  '1057': 'Negatron Cloak',
#  '1058': 'Needlessly Large Rod',
#  '1082': 'Dark Seal',
#  '1083': 'Cull',
#  '2003': 'Health Potion',
#  '2010': 'Total Biscuit of Everlasting Will',
#  '2015': 'Kircheis Shard',
#  '2031': 'Refillable Potion',
#  '2033': 'Corrupting Potion',
#  '2051': "Guardian's Horn",
#  '2052': 'Poro-Snax',
#  '2055': 'Control Ward',
# ...

# %%
amirs_games["item0"]=amirs_games["item0"].map(dictionaryOfItems)
amirs_games["item1"]=amirs_games["item1"].map(dictionaryOfItems)
amirs_games["item2"]=amirs_games["item2"].map(dictionaryOfItems)
amirs_games["item3"]=amirs_games["item3"].map(dictionaryOfItems)
amirs_games["item4"]=amirs_games["item4"].map(dictionaryOfItems)
amirs_games["item5"]=amirs_games["item5"].map(dictionaryOfItems)
amirs_games["item6"]=amirs_games["item6"].map(dictionaryOfItems)
# Out:
# <ipython-input-154-6d8d4153d10b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item0"]=amirs_games["item0"].map(dictionaryOfItems)
# <ipython-input-154-6d8d4153d10b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amirs_games["item1"]=amirs_games["item1"].map(dictionaryOfItems)
# <ipython-input-154-6d8d4153d10b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
amirs_games["item5"]
# Out:
# 9               Control Ward
# 14                       NaN
# 22              Oblivion Orb
# 33          Cloak of Agility
# 43                      Zeal
# 52          Cloak of Agility
# 66       Tear of the Goddess
# 77                    Dagger
# 87                       NaN
# 92            Morellonomicon
# 107            Blasting Wand
# 117            Bloodthirster
# 122             Oblivion Orb
# 132                      NaN
# 143                   Dagger
# 152    Executioner's Calling
# 162         Vampiric Scepter
# 178                      NaN
# 188                    Sheen
# 198                      NaN
# 208                     Zeal
# 213                      NaN
# 228                      NaN
# 233                      NaN
# 248                   Dagger
# 258                      NaN
# 269           Ravenous Hydra
# 278              B. F. Sword
# 283                      NaN
# 293               Long Sword
# 303                  Pickaxe
# 313           Sanguine Blade
# ...

# %%
pd.plotting.scatter_matrix(amirs_games)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-a90db7b489ca> in <module>
# ----> 1 pd.plotting.scatter_matrix(amirs_games)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwargs)
#     126     """
#     127     plot_backend = _get_plot_backend("matplotlib")
# --> 128     return plot_backend.scatter_matrix(
#     129         frame=frame,
#     130         alpha=alpha,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\plotting\_matplotlib\misc.py in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#      28     n = df.columns.size
#      29     naxes = n * n
# ---> 30     fig, axes = _subplots(naxes=naxes, figsize=figsize, ax=ax, squeeze=False)
#      31
# ...
