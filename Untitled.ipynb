# %%
import requests
import json
import pandas as pd
import time

# %%
apikey='RGAPI-e93fb6b8-50fb-477b-a61a-4aa0f5b00e38'
myresp= requests.get('https://na1.api.riotgames.com/lol/summoner/v4/summoners/by-name/reydeloscriollos?api_key={}'.format(apikey))
apimatch='uEvGlJu4J6pqdXxzBvDxSj3MZ7iV1MfdmexJIl7LZlfZkQ7OdGNbfICivYPH_59NNoUitWoo3tVUzA'
sndresp=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/kaRj0TF9dJQpxiAXS9DukCLbfuiT9aAVSDbSkm329KWSkqzi87iE6HlEBuUdRMjcpt-XcFy0yQs3kw/ids?start=0&count=50&api_key={}'.format(apikey))

# %%
sndresp
# Out:
# <Response [200]>

# %%
myresp
# Out:
# <Response [200]>

# %%
myresp.json()
# Out:
# {'id': '8_ogx0Ro8pJixXDSZLKaqgtH0XSRuC5jndwdchQ9odzcTqQ',
#  'accountId': '_5IqpvWSbxIpp5xb68Ea3Ip5NlutvRklZBI5xUbV0vO3pA',
#  'puuid': 'kaRj0TF9dJQpxiAXS9DukCLbfuiT9aAVSDbSkm329KWSkqzi87iE6HlEBuUdRMjcpt-XcFy0yQs3kw',
#  'name': 'reydeloscriollos',
#  'profileIconId': 4804,
#  'revisionDate': 1620186415000,
#  'summonerLevel': 197}

# %%
sndresp.json()
type(sndresp.json())
# Out:
# list

# %%
test_match=sndresp.json()
test_match

dictionaryOfPlayers={}
counter=0

for item in test_match:
    
    
    time.sleep(5)
    my_match_in_for=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/{}?api_key={}'.format(item,apikey))
    vari=my_match_in_for.json()
    
    dictionaryOfPlayers[counter]= vari['info']['participants']
    counter+=1

# %%
for player in dictionaryOfPlayers[0]:
    print(player)
    del player['perks']
# Out:
# {'assists': 0, 'baronKills': 0, 'bountyLevel': 0, 'champExperience': 10374, 'champLevel': 13, 'championId': 887, 'championName': 'Gwen', 'championTransform': 0, 'consumablesPurchased': 2, 'damageDealtToBuildings': 137, 'damageDealtToObjectives': 137, 'damageDealtToTurrets': 137, 'damageSelfMitigated': 13717, 'deaths': 5, 'detectorWardsPlaced': 0, 'doubleKills': 0, 'dragonKills': 0, 'firstBloodAssist': False, 'firstBloodKill': False, 'firstTowerAssist': False, 'firstTowerKill': False, 'gameEndedInEarlySurrender': False, 'gameEndedInSurrender': False, 'goldEarned': 7243, 'goldSpent': 6200, 'individualPosition': 'TOP', 'inhibitorKills': 0, 'inhibitorsLost': 3, 'item0': 1056, 'item1': 4633, 'item2': 3158, 'item3': 3057, 'item4': 3113, 'item5': 0, 'item6': 3340, 'itemsPurchased': 13, 'killingSprees': 0, 'kills': 3, 'lane': 'MIDDLE', 'largestCriticalStrike': 0, 'largestKillingSpree': 0, 'largestMultiKill': 1, 'longestTimeSpentLiving': 571, 'magicDamageDealt': 28927, 'magicDamageDealtToCham
# ...

# %%
list_of_frames=[]
for dataframe2 in  dictionaryOfPlayers:
    list_of_frames.append(pd.DataFrame(dictionaryOfPlayers[dataframe2]))
    
    
df_pd=pd.concat(list_of_frames,ignore_index=True)

# %%
### this is just just test code this can be ignored
to_conca=[pd.DataFrame(dictionaryOfPlayers[1]),pd.DataFrame(dictionaryOfPlayers[0])]
findat=pd.concat(to_conca,ignore_index=True)

findat
# Out:
#     assists  baronKills  bountyLevel  champExperience  champLevel  championId  \
# 0         7           0            9            16409          16          17
# 1        17           1            1            13774          15          25
# 2         8           0            1            13666          15         157
# 3         5           0            0            11714          14         235
# 4        13           0            1            11186          13          37
# 5         5           0            1            14268          15          98
# 6         6           0            1            11493          14          33
# 7         4           0            0            11031          13         236
# 8         1           0            0            11275          13          15
# 9         5           0            0             8736          12          99
# 10        0           0            0            10374          13         887
# ...

# %%
for item in df_pd.columns:
    print(item)
# Out:
# assists
# baronKills
# bountyLevel
# champExperience
# champLevel
# championId
# championName
# championTransform
# consumablesPurchased
# damageDealtToBuildings
# damageDealtToObjectives
# damageDealtToTurrets
# damageSelfMitigated
# deaths
# detectorWardsPlaced
# doubleKills
# dragonKills
# firstBloodAssist
# firstBloodKill
# firstTowerAssist
# firstTowerKill
# gameEndedInEarlySurrender
# gameEndedInSurrender
# goldEarned
# goldSpent
# individualPosition
# inhibitorKills
# inhibitorsLost
# item0
# item1
# item2
# item3
# item4
# item5
# item6
# itemsPurchased
# killingSprees
# kills
# lane
# largestCriticalStrike
# largestKillingSpree
# largestMultiKill
# longestTimeSpentLiving
# magicDamageDealt
# magicDamageDealtToChampions
# magicDamageTaken
# neutralMinionsKilled
# nexusKills
# nexusLost
# objectivesStolen
# objectivesStolenAssists
# participantId
# pentaKills
# physicalDamageDealt
# physicalDamageDealtToChampions
# physicalDamageTaken
# profileIcon
# puuid
# quadraKills
# ...

# %%
df_pd.info
amirs_games=df_pd.loc[df_pd['summonerName']=='reydeloscriollos']
# Out:
#      assists  baronKills  bountyLevel  champExperience  champLevel  \
# 3          3           0            0             9597          12
# 13         5           0            0            11714          14
# 22        13           0            5            18524          18
# 36         8           1            1            14781          16
# 47         4           0            0            13733          15
# 57         0           0            0             1025           3
# 62        22           0            3            23544          18
# 77         8           0            1            16057          16
# 87        12           1            0            26694          18
# 92         8           0            4            15525          16
# 102        1           0            1             8742          12
# 113       23           0            0            16552          17
# 122        8           1            0            13632          15
# ...

# %%
amirs_games["item0"]
# Out:
# 3      6672
# 13     6672
# 22     3042
# 36     6653
# 47     3070
# 57     1055
# 62     3040
# 77     3070
# 87     3006
# 92     3070
# 102    1055
# 113    3042
# 122    3070
# 132    3123
# 148    1055
# 158    3031
# 168    6672
# 178    3070
# 183    1055
# 198    3004
# 203    3026
# 218    1053
# 228    1055
# 239    6692
# 248    3042
# 253    1083
# 263    3184
# 273    3184
# 283    3042
# 293    6671
# 302    3040
# 317    3040
# 323    6672
# 339    3864
# 342    3070
# 351    6691
# 367    3070
# 378    3042
# 382    3070
# 393    1055
# 401    6664
# 416    4633
# 422    3070
# 433    3070
# 442    3040
# 453    3033
# 462    3070
# 478    3042
# 482    3070
# 492    3040
# Name: item0, dtype: int64

# %%
item_req=requests.get('http://ddragon.leagueoflegends.com/cdn/9.3.1/data/en_US/item.json')

# %%
item_req.json()
# Out:
# {'type': 'item',
#  'version': '9.3.1',
#  'basic': {'name': '',
#   'rune': {'isrune': False, 'tier': 1, 'type': 'red'},
#   'gold': {'base': 0, 'total': 0, 'sell': 0, 'purchasable': False},
#   'group': '',
#   'description': '',
#   'colloq': ';',
#   'plaintext': '',
#   'consumed': False,
#   'stacks': 1,
#   'depth': 1,
#   'consumeOnFull': False,
#   'from': [],
#   'into': [],
#   'specialRecipe': 0,
#   'inStore': True,
#   'hideFromAll': False,
#   'requiredChampion': '',
#   'requiredAlly': '',
#   'stats': {'FlatHPPoolMod': 0,
#    'rFlatHPModPerLevel': 0,
#    'FlatMPPoolMod': 0,
#    'rFlatMPModPerLevel': 0,
#    'PercentHPPoolMod': 0,
#    'PercentMPPoolMod': 0,
#    'FlatHPRegenMod': 0,
#    'rFlatHPRegenModPerLevel': 0,
#    'PercentHPRegenMod': 0,
#    'FlatMPRegenMod': 0,
#    'rFlatMPRegenModPerLevel': 0,
#    'PercentMPRegenMod': 0,
#    'FlatArmorMod': 0,
#    'rFlatArmorModPerLevel': 0,
#    'PercentArmorMod': 0,
#    'rFlatArmorPenetrationMod': 0,
# ...

# %%
my_match=requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3913284076?api_key={}'.format(apikey))

# %%
basegame=my_match.json()
list_of_players_in_game=basegame['info']['participants']

for player in list_of_players_in_game:
    
    print(player)
